# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
clima = pd.read_csv('./seattle-weather.csv')
climadrop = clima.drop(columns=['date'])
climadrop
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
climadrop_copy = climadrop.copy()
climadrop_copy
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
x = climadrop_copy.drop(columns=['weather'])
y = climadrop_copy['weather']

# %%
x
# Out:
#       precipitation  temp_max  temp_min  wind
# 0               0.0      12.8       5.0   4.7
# 1              10.9      10.6       2.8   4.5
# 2               0.8      11.7       7.2   2.3
# 3              20.3      12.2       5.6   4.7
# 4               1.3       8.9       2.8   6.1
# ...             ...       ...       ...   ...
# 1456            8.6       4.4       1.7   2.9
# 1457            1.5       5.0       1.7   1.3
# 1458            0.0       7.2       0.6   2.6
# 1459            0.0       5.6      -1.0   3.4
# 1460            0.0       5.6      -2.1   3.5
#
# [1461 rows x 4 columns]

# %%
y
# Out:
# 0       drizzle
# 1          rain
# 2          rain
# 3          rain
# 4          rain
#          ...
# 1456       rain
# 1457       rain
# 1458        fog
# 1459        sun
# 1460        sun
# Name: weather, Length: 1461, dtype: object

# %%
label_encoder = LabelEncoder()
y_num = label_encoder.fit_transform(y) + 1

# %%
valores = np.unique(y_num)

# %%
# División de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(x, y_num, test_size=0.3, random_state=15)

# Verificación de las dimensiones de los conjuntos de datos
print(f"Forma de X_train: {X_train.shape}")
print(f"Forma de X_test: {X_test.shape}")
print(f"Forma de x: {x.shape}")
# Out:
# Forma de X_train: (1022, 4)
# Forma de X_test: (439, 4)
# Forma de x: (1461, 4)
